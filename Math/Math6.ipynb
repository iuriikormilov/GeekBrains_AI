# %% [markdown]
# <h1>Тема “Элементы теории вероятностей”</h1>
# <h3>Задание 1 (теорема сложения)</h3>
# Найти вероятность выпадения 2 или 5 очков при подбрасывании игральной кости, на гранях которой имеются соответственно 1,2,3,4,5 и 6 очков.

# %% [markdown]
# Вероятность выпадения 2 равна 1/6, выпадения 5 также 1/6, по теореме сложения вероятность выпадения 2 или 5 равна 1/6+1/6 = 1/3

# %% [markdown]
# <h3>Задание 2 (теорема умножения)</h3>
# Найти вероятность того, что при двух подбрасываниях той же самой игральной кости сначала выпадет 2, а затем 5.

# %% [markdown]
# 1/36

# %% [markdown]
# <h3>Задание 3 </h3>
# Найти вероятность выпадения 2 и 5 очков при двух подбрасываниях той же самой игральной игральной кости.

# %% [markdown]
# Нас интересует два варианта:
# <p>1) выпадение 2 в первый раз и 5 во второй (вероятность этого 1/36)</p>
# <p>2) выпадение 5 в первый раз и 2 во второй (вероятность этого также 1/36). </p><p>Значит искомая вероятность будет равна сумме сумме вероятность и равна 1/18

# %% [markdown]
# <h3>Задание 4 (Геометрическая вероятность +интервалы)</h3>
# На отрезке AB длиной 20 см наугад отметили точку C. Какова вероятность, что она находится на расстоянии не более 9 см от точки А и не более 15 см от точки В?

# %% [markdown]
# Будем считать, что выбор любой точки равновероятен. Искомый отрезок будет равен 4 см (9-(20-15)). Следовательно вероятность попадения в этот отрезок равна 4/20 или 0.2.

# %% [markdown]
# <h3>Задание 5</h3>
# Телефонный номер состоит из 7 цифр. Какова вероятность, что это номер 8882227?

# %% [markdown]
# Будем считать, что на любом месте может находиться цифры от 0 до 9, тогда вероятность 8 на первом месте равна 0.1, вероятность 8 на втором месте равна 0.1 и т. д. Вероятность такого номера $\frac{1}{10^7}$

# %% [markdown]
# <h3>Задание 6</h3>
# Набирая номер телефона, абонент забыл 2 последние цифры, и, помня только то, что эти цифры различны и среди них нет нуля, стал набирать их наудачу. Сколько вариантов ему надо перебрать, чтобы наверняка найти нужный номер? Какова вероятность того, что он угадает номер с первого раза?

# %% [markdown]
# Вариантов исхода 9*8. Вероятность отгадать с первого раза 1/72
